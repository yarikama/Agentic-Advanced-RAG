# %%
import pandas as pd
Graph_rag_artifacts = ""
doc_df = pd.read_parquet(f"{Graph_rag_artifacts}/create_final_community_reports.parquet")
doc_df.head(5)
# Out:
#   community                                       full_content  level  rank  \
# 0       534  # Dwayne, Jay, and the Dynamics of Crime\n\nTh...      4   9.0
# 1       535  # Donner-Wells National Bank and the Robbery N...      4   8.5
# 2       536  # Caterina and Pasqualino: Love Amidst War\n\n...      4   9.0
# 3       537  # Pasqualino and the Dynamics of Community\n\n...      4   9.0
# 4       538  # Clay, Aisha, and the Dynamics of Conflict\n\...      4   9.0
#
#                                                title  \
# 0             Dwayne, Jay, and the Dynamics of Crime
# 1  Donner-Wells National Bank and the Robbery Nar...
# 2           Caterina and Pasqualino: Love Amidst War
# 3           Pasqualino and the Dynamics of Community
# 4          Clay, Aisha, and the Dynamics of Conflict
#
#                                     rank_explanation  \
# 0  The narrative provides deep insights into char...
# 1  The narrative is highly significant as it expl...
# 2  The narrative is highly significant as it expl...
# 3  The narrative provides deep insights into char...
# 4  The narrative is highly significant as it intr...
#
#                                              summary  \
# 0  The community centers around the characters Dw...
# 1  The community centers around the Donner-Wells ...
# 2  The community centers around the characters Ca...
# 3  The community centers around Pasqualino, a you...
# 4  This community centers around the complex rela...
#
#                                             findings  \
# 0  [{'explanation': 'Dwayne is portrayed as a mul...
# 1  [{'explanation': 'The Donner-Wells National Ba...
# 2  [{'explanation': 'Caterina represents the emot...
# 3  [{'explanation': 'Pasqualino's character is pi...
# 4  [{'explanation': 'The bathroom serves as a mul...
#
#                                    full_content_json  \
# 0  {\n    "title": "Dwayne, Jay, and the Dynamics...
# 1  {\n    "title": "Donner-Wells National Bank an...
# 2  {\n    "title": "Caterina and Pasqualino: Love...
# 3  {\n    "title": "Pasqualino and the Dynamics o...
# 4  {\n    "title": "Clay, Aisha, and the Dynamics...
#
#                                      id  \
# 0  cc180d9f-9abc-4459-938b-c70e3c62d877
# 1  51cf5ae2-e257-4253-bb90-69c5540dea08
# 2  43d79808-0fd1-402d-9c1e-3313a0ac8363
# 3  b7961940-b66b-4c7d-a9b0-9ebf926265df
# 4  c8f0e5ff-0025-4f06-a5e5-bb70b5dcec02
#
#                               full_content_embedding  \
# 0  [0.03856884315609932, 0.06392262130975723, -0....
# 1  [0.010677372105419636, 0.021481269970536232, -...
# 2  [0.044687822461128235, -0.004155505448579788, ...
# 3  [0.03973129764199257, 0.03397233784198761, 0.0...
# 4  [0.041022852063179016, 0.05283648893237114, 0....
#
#                                    summary_embedding  \
# 0  [0.019128641113638878, 0.05514286831021309, -0...
# 1  [-0.0006910123047418892, 0.012934575788676739,...
# 2  [0.024521034210920334, -0.00991173554211855, 0...
# 3  [0.014332879334688187, 0.019663406535983086, -...
# 4  [0.047144606709480286, 0.054332319647073746, 0...
#
#                                      title_embedding
# 0  [0.041969262063503265, 0.04299576207995415, -0...
# 1  [0.019868899136781693, 0.004599020350724459, -...
# 2  [-0.002926247427240014, -0.005339326336979866,...
# 3  [0.009135249070823193, 0.014460430480539799, 0...
# 4  [0.0344376303255558, 0.031317442655563354, 0.0...

# %%
text_df = pd.read_parquet(f"{Graph_rag_artifacts}/create_final_documents.parquet")
text_df.head(10)
# Out:
#                                  id  \
# 0  474865e9db94180d0d99e5125ae04f2b
# 1  dc56f172618f7849cb1cd4075359c4bb
# 2  ced2aa9c52ef54e51b9961e5bb700ce8
# 3  0015e9b933802296eb40df4f7a5cd5f3
# 4  d669afeb39840bfff0bcd7c6b91f9ed2
# 5  891d7750d00471fb1ae1698a9f7b4649
# 6  334263fbf4fe97c259f4605ee3f88e4a
# 7  9dab1b367c9059213c5d1b3f6987063f
# 8  bdcc06ddfcd35733b86d19d33e197436
# 9  93c3caf1bd940300d3934def3342e9b4
#
#                                        text_unit_ids  \
# 0  [a2a6bc7fdeba51d448c87fd4b30ca1e8, 877021065a3...
# 1  [fa119fc2d9dd1d9dacc117dfe72c5eb1, f7044ed1e87...
# 2  [02b8e6474d15872c240b380b02695d8b, 647bb367d0f...
# 3  [057ff759b344cdcdea9924678f13e0b6, 9ed083c1a30...
# 4  [a4873201168b6cef777106d6d8eb1252, e533c97c92d...
# 5  [7f3a9c6c273822abb5ef5ed44a30388c, 89044e23b6b...
# 6  [39eb7760cbc357b960111d4f70cc4b5a, c0f89e16340...
# 7  [1c03941cb315cba0f6c71ad3858a259b, 0499c6910d3...
# 8  [d799e380a6886292b97fcd0399e24cc9, 1f3b60a8a72...
# 9  [87bab010b6bd6e6178a871c36f9a9702, f6794b45a54...
#
#                                          raw_content  \
# 0  Rise of the Guardians Script at IMSDb. The Int...
# 1  ïProject Gutenbergs The Adventure of the Cardb...
# 2  ï\nProject Gutenberg Etext of The Two Noble Ki...
# 3  Yes Man Script at IMSDb. The Internet Movie Sc...
# 4  ïThe Project Gutenberg EBook of Honorine, by H...
# 5  Losers, The Script at IMSDb. The Internet Movi...
# 6  30 Minutes or Less Script at IMSDb. The Intern...
# 7  ïThe Project Gutenberg EBook of Up and Down, b...
# 8  Fight Club Script at IMSDb. The Internet Movie...
# 9  ïThe Project Gutenberg eBook, The Velveteen Ra...
#
#                                               title  \
# 0                   movie_Rise_of_the_Guardians.txt
# 1  gutenberg_The_Adventure_of_the_Cardboard_Box.txt
# 2               gutenberg_The_Two_Noble_Kinsmen.txt
# 3                          movie_Yes_Man_(film).txt
# 4                    gutenberg_Honorine_(novel).txt
# 5                       movie_The_Losers_(film).txt
# 6                      movie_30_Minutes_or_Less.txt
# 7               gutenberg_Up_the_Down_Staircase.txt
# 8                              movie_Fight_Club.txt
# 9                gutenberg_The_Velveteen_Rabbit.txt
#
#                                raw_content_embedding
# 0  [0.016017707094181693, 0.02192370068985526, -0...
# 1  [0.03423983798018732, 0.030299222168653692, 0....
# 2  [0.025818965711460296, -0.005006590026035357, ...
# 3  [-0.004085862007900637, 0.06060061392146095, -...
# 4  [0.04183741774840568, -0.005394737567381131, -...
# 5  [0.038726556590146434, 0.0687152017513619, -0....
# 6  [0.0289137006752739, 0.05350888241440725, -0.0...
# 7  [0.04453242472321056, 0.014038797790324152, -0...
# 8  [0.007852849433199692, 0.05423429285490744, -0...
# 9  [0.015096407931084169, 0.03629314756469123, 0....
